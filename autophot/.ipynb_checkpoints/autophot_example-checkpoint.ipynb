# %% [markdown]
# AutoPHoT Example script to highligh basic operations of package

# %%
import autophot

# %% [markdown]
# utophot requires input based on input datalist of parameters
# * Many of these are initial guesses and will be changed
